# %%
from matplotlib import pyplot as plt

# %%
day = ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday']
temp = [31, 28, 26, 32, 35, 36, 37]

# %%
plt.plot(day, temp, color='green', marker='o', markersize=5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %% [markdown]
# ### Data Collection and Processing

# %%
gold_price = pd.read_csv('gld_price_data.csv')
gold_price
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# Statistical measurement of data 
gold_price.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
# Number of rows and columns
gold_price.shape
# Out:
# (2290, 6)

# %%
# getting some basic information about data
gold_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
# checking number of missing values
gold_price.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# ## Correlation
# 1. Positive Correlation
# 2. Negative Correlation

# %%
crl = gold_price.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(crl, annot=True, annot_kws={'size':10},  fmt='.1f')
# Out:
# <Axes: >

# %%
# Correlation Values of Gold
crl['GLD']
# Out:
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
# checking the distribution of gold price 
sns.histplot(gold_price['GLD'])
# Out:
# <Axes: xlabel='GLD', ylabel='Count'>

# %% [markdown]
# ## Splitting the Features and Target

# %%
x = gold_price.drop(['Date', 'GLD'], axis=1)
y = gold_price['GLD']

# %%
x
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
y
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %% [markdown]
# ### splitting into training data and testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Model Training: Random Forest Regressor

# %%
regressor = RandomForestRegressor(n_estimators=100, random_state=2)

# %%
# training the model
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=2)

# %% [markdown]
# ### Model Evaluation

# %%
# Prediction on test data
test_data_prediction = regressor.predict(x_test)
test_data_prediction
# Out:
# array([168.14679949,  82.24339964, 116.2091003 , 127.75390099,
#        120.68560157, 154.80879758, 149.66389771, 126.11980063,
#        117.46109873, 126.11890065, 116.8192012 , 171.67110076,
#        142.04309863, 167.79609845, 115.15130022, 117.81390058,
#        139.19030274, 170.20570075, 159.16530239, 159.13609887,
#        155.07470026, 125.24170007, 176.16490017, 156.86490313,
#        125.25400031,  93.86899998,  76.7901002 , 120.7469001 ,
#        119.14609953, 167.59019972,  88.18590001, 125.25969994,
#         91.08590068, 117.57440042, 121.07519911, 136.48370094,
#        115.53470088, 115.35480078, 149.37649963, 107.14580109,
#        104.23500253,  87.24959778, 126.49140041, 118.20639983,
#        153.30559911, 119.71289971, 108.43879997, 108.02389812,
#         92.98830022, 127.21629761,  75.56760045, 113.78179947,
#        121.32899992, 111.32629931, 118.89129884, 120.79729954,
#        158.50929988, 168.40700101, 147.09549665,  85.79419855,
#         94.23150038,  86.79829922,  90.46990009, 119.01690071,
#        126.48540064, 127.6097004 , 170.28950003, 122.2563994 ,
#        117.5067989 ,  98.42460012, 168.00520027, 142.66339862,
#        131.93010349, 121.09090193, 121.0715994 , 119.86200042,
#        114.57850177, 118.27940079, 107.11430112, 127.83190094,
#        114.27179942, 106.87570003, 117.2036005 , 119.54149847,
#         88.94420097,  88.27969863, 146.42740189, 127.26990005,
#        113.1682003 , 110.31819845, 108.15739898,  77.23979919,
#        169.65440213, 114.06039914, 121.71359893, 128.15580182,
#        154.91249832,  91.67139925, 136.64710159, 158.45090328,
#        125.53420051, 125.20270035, 130.64270176, 114.98090133,
#        119.84580035,  92.07209975, 110.03029859, 167.53919912,
#        156.85669954, 114.3742999 , 106.67310119,  79.46819994,
#        112.97680035, 125.9539008 , 107.06599922, 119.55770103,
#         93.95719943, 119.77460043, 113.21450111,  94.26809921,
#        108.81679969,  87.23029917, 109.48129925,  89.68289986,
#         92.48610002, 131.60940294, 162.36050102,  89.19350026,
#        119.53390077, 133.18250157, 123.96560024, 128.27910267,
#        101.9396983 ,  88.85709845, 132.58480086, 119.59720056,
#        108.44099995, 168.39530093, 115.11900051,  86.65319896,
#        118.78490052,  90.97749963, 161.70150077, 116.5709005 ,
#        121.3904002 , 159.98179818, 120.23319919, 112.43759999,
#        108.44029856, 126.70100007,  75.95550056, 102.98819981,
#        127.69250267, 121.75009914,  92.52270012, 131.85570094,
#        118.1652012 , 115.69209993, 154.73050256, 158.38420124,
#        110.06379942, 153.8098974 , 119.35910118, 160.43600096,
#        118.6864004 , 157.66129891, 115.05949928, 116.3840002 ,
#        147.81279846, 114.98080077, 126.02919897, 165.99489917,
#        117.66520019, 125.21829917, 153.32420366, 153.45180231,
#        132.22340002, 114.87930026, 121.1743019 , 125.0270003 ,
#         89.76030062, 123.20979979, 154.68330111, 111.7581002 ,
#        106.53370012, 161.9364017 , 118.52029992, 165.78049985,
#        134.12110113, 114.86929982, 152.93029813, 168.70389986,
#        114.74640022, 113.97610102, 159.00979879,  85.062699  ,
#        127.12380062, 127.81920067, 128.74059927, 124.33900071,
#        124.00290079,  90.57820055, 153.17869946,  97.21499957,
#        136.98489963,  89.18929927, 106.88260021, 114.98410036,
#        112.47250061, 124.37229938,  91.47249849, 125.49190125,
#        162.35309873, 120.15969881, 164.9900009 , 126.78279819,
#        112.51559994, 127.50549936,  94.8436989 ,  91.04350005,
#        103.366199  , 120.7919999 ,  83.51699977, 126.27049918,
#        160.1613044 , 117.22350081, 118.34099982, 120.04680007,
#        122.85859951, 120.12740136, 121.39620002, 118.00350052,
#        107.00610029, 148.13929923, 126.42499845, 115.72630098,
#         73.7619002 , 127.82740101, 153.86150044, 122.22899961,
#        125.55670022,  88.88469999, 103.1440989 , 124.76440053,
#        120.27800023,  73.29480098, 151.49369977, 121.14440022,
#        104.88220056,  86.36179767, 115.29259956, 172.2250983 ,
#        119.92910032, 159.37519749, 113.18999953, 121.05820007,
#        118.70960093,  95.81619982, 118.71589982, 125.85290046,
#        118.54119959,  95.96920071, 154.02170172, 121.93650012,
#        147.57919992, 158.78910314, 113.99880026, 122.47909952,
#        151.47469857, 127.5318004 , 165.59700092, 135.29450045,
#        120.0301997 , 167.29479823, 108.40689922, 121.44719901,
#        138.53530124, 107.28139895])

# %% [markdown]
# ## Compare actual values and predicted value

# %%
# R squared error
error_score = metrics.r2_score(y_test, test_data_prediction)
print('R Squared error: ', error_score)
# Out:
# R Squared error:  0.9886241205255454

# %%
y_test = list(y_test)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, color='blue', label='Actual Value')
plt.plot(test_data_prediction, color='red', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of Values')
plt.ylabel('Gold Price')
plt.legend()
plt.show()
